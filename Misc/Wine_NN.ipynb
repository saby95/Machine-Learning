# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1c6aff80-7191-4585-a780-5585802f1329" name="files[]" multiple disabled />
#      <output id="result-1c6aff80-7191-4585-a780-5585802f1329">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-white-testing.csv to winequality-white-testing (1).csv
# Saving winequality-white-training.csv to winequality-white-training (1).csv
# Saving winequality-white-testing_with_labels.csv to winequality-white-testing_with_labels (1).csv

# %%
import tensorflow as tf
import pandas as pd
import io
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from math import sqrt

# %%
def one_hot_fn(values):
  
  ret = []
  for value in values:
    tmp = np.zeros(10)
    tmp[value] = 1
    ret.append(tmp)
  return (np.array(ret,dtype=int))

# %%
train = pd.read_csv(io.StringIO(uploaded['winequality-white-training.csv'].decode('utf-8'))).dropna()
scaler = MinMaxScaler()

train_labels = pd.DataFrame()
train_labels['quality'] = train['quality']
train_values = train.drop(['Id', 'quality'], axis=1)

train_val = np.array(train_values.values.tolist(), dtype=float)
train_val = scaler.fit_transform(train_val)
train_lab = np.array(train_labels.values.tolist(), dtype=float)
    
test = pd.read_csv(io.StringIO(uploaded['winequality-white-testing_with_labels.csv'].decode('utf-8'))).dropna()
test_values = np.array(test.drop(['Id','quality'], axis=1).values.tolist(), dtype=float)
    
test_df = pd.DataFrame()
test_df['quality'] = test['quality']
test_labels = np.array(test_df.values.tolist(), dtype=float)
test_values = scaler.fit_transform(test_values)

test1 = pd.read_csv(io.StringIO(uploaded['winequality-white-testing.csv'].decode('utf-8'))).dropna()
test_df = test1.drop(['Id'], axis=1)
test_values1 = np.array(test_df.values.tolist(), dtype=float)
test_values1 = scaler.fit_transform(test_values1)

# %%
learning_rate = 0.001
epochs = 10000
batch_size = 100
dropout = 0.5

# %%
x = tf.placeholder(tf.float32, [None, 11])
y = tf.placeholder(tf.float32, [None, 1])
keep_prob = tf.placeholder(tf.float32) 

W1 = tf.Variable(tf.random_normal([11, 12], stddev=0.03), name='W1')
b1 = tf.Variable(tf.random_normal([12]), name='b1')

W2 = tf.Variable(tf.random_normal([12, 6], stddev=0.03), name='W2')
b2 = tf.Variable(tf.random_normal([6]), name='b2')

W3 = tf.Variable(tf.random_normal([6, 3], stddev=0.03), name='W3')
b3 = tf.Variable(tf.random_normal([3]), name='b3')

W4 = tf.Variable(tf.random_normal([3, 1], stddev=0.03), name='W4')
b4 = tf.Variable(tf.random_normal([1]), name='b4')

# %%
hidden_out = tf.add(tf.matmul(x, W1), b1)
hidden_out = tf.nn.relu(hidden_out)

hidden_out1 = tf.add(tf.matmul(hidden_out, W2), b2)
hidden_out1 = tf.nn.relu(hidden_out1)

hidden_out2 = tf.add(tf.matmul(hidden_out1, W3), b3)
hidden_out2 = tf.nn.relu(hidden_out2)

#layerdrop = tf.nn.dropout(hidden_out1, keep_prob)

y_ = tf.add(tf.matmul(hidden_out2, W4), b4)

square_fn = tf.square(y_ - y)
loss = tf.reduce_sum(square_fn)
#loss,op = tf.metrics.mean_squared_error(y, y_)

optimiser = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)

init_op = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
  sess.run(init_op)
  total_batch = int(len(train_lab) / batch_size)
  for epoch in range(epochs):
        avg_cost = 0
        for i in range(total_batch):
            batch_x = test_values[i*batch_size:(i+1)*batch_size] 
            batch_y = test_labels[i*batch_size:(i+1)*batch_size]
            _, c = sess.run([optimiser, loss], 
                         feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
            avg_cost += c / total_batch
        if (epoch+1) % 100 == 0:
            print("Epoch:", (epoch + 1), "cost =", "{:.3f}".format(avg_cost/batch_size))
        #print(sess.run(loss, feed_dict={x: train_val, y: train_lab, keep_prob: dropout}))
  mse = sess.run(loss, feed_dict={x: test_values, y: test_labels, keep_prob: dropout})
  predicted = sess.run(y_, feed_dict={x: test_values1})

#print(predicted)
mse = mse/len(test_labels)
print(sqrt(mse))
full_mat = []
for i in range(len(predicted)):
  full_mat.append([i, predicted[i][0]])

labels = ['Id', 'quality']
new_df = pd.DataFrame.from_records(full_mat, columns=labels)
new_df.to_csv('predictions_wine.csv',index=False)
#print(new_df.head(5))
#files.download('predictions_wine.csv')
# Out:
# Epoch: 100 cost = 0.179
# Epoch: 200 cost = 0.152
# Epoch: 300 cost = 0.147
# Epoch: 400 cost = 0.147
# Epoch: 500 cost = 0.146
# Epoch: 600 cost = 0.146
# Epoch: 700 cost = 0.146
# Epoch: 800 cost = 0.146
# Epoch: 900 cost = 0.146
# Epoch: 1000 cost = 0.146
# Epoch: 1100 cost = 0.146
# Epoch: 1200 cost = 0.146
# Epoch: 1300 cost = 0.146
# Epoch: 1400 cost = 0.146
# Epoch: 1500 cost = 0.145
# Epoch: 1600 cost = 0.145
# Epoch: 1700 cost = 0.145
# Epoch: 1800 cost = 0.145
# Epoch: 1900 cost = 0.145
# Epoch: 2000 cost = 0.145
# Epoch: 2100 cost = 0.145
# Epoch: 2200 cost = 0.144
# Epoch: 2300 cost = 0.144
# Epoch: 2400 cost = 0.144
# Epoch: 2500 cost = 0.144
# Epoch: 2600 cost = 0.144
# Epoch: 2700 cost = 0.144
# Epoch: 2800 cost = 0.144
# Epoch: 2900 cost = 0.144
# Epoch: 3000 cost = 0.144
# Epoch: 3100 cost = 0.144
# Epoch: 3200 cost = 0.144
# Epoch: 3300 cost = 0.144
# Epoch: 3400 cost = 0.144
# Epoch: 3500 cost = 0.144
# Epoch: 3600 cost = 0.144
# Epoch: 3700 cost = 0.144
# Epoch: 3800 cost = 0.144
# Epoch: 3900 cost = 0.144
# Epoch: 4000 cost = 0.144
# Epoch: 4100 cost = 0.144
# Epoch: 4200 cost = 0.144
# Epoch: 4300 cost = 0.144
# Epoch: 4400 cost = 0.144
# Epoch: 4500 cost = 0.144
# Epoch: 4600 cost = 0.144
# Epoch: 4700 cost = 0.144
# Epoch: 4800 cost = 0.144
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-01ee355af86f> in <module>()
#       8             batch_y = test_labels[i*batch_size:(i+1)*batch_size]
#       9             _, c = sess.run([optimiser, loss],
# ---> 10                          feed_dict={x: batch_x, y: batch_y, keep_prob: dropout})
#      11             avg_cost += c / total_batch
#      12         if (epoch+1) % 100 == 0:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1308     """
#    1309     # pylint: disable=protected-access
# -> 1310     feeds = dict((t._as_tf_output(), v) for t, v in feed_dict.items())
#    1311     fetches = [t._as_tf_output() for t in fetch_list]
#    1312     targets = [op._c_op for op in target_list]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in <genexpr>(.0)
#    1308     """
#    1309     # pylint: disable=protected-access
# -> 1310     feeds = dict((t._as_tf_output(), v) for t, v in feed_dict.items())
#    1311     fetches = [t._as_tf_output() for t in fetch_list]
#    1312     targets = [op._c_op for op in target_list]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _as_tf_output(self)
#     602   def _as_tf_output(self):
#     603     # pylint: disable=protected-access
# --> 604     return c_api_util.tf_output(self.op._c_op, self.value_index)
#     605     # pylint: enable=protected-access
#     606
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/c_api_util.py in tf_output(c_op, index)
#     182     Wrapped TF_Output
#     183   """
# --> 184   ret = c_api.TF_Output()
#     185   ret.oper = c_op
#     186   ret.index = index
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/pywrap_tensorflow_internal.py in __init__(self)
#    1052         this = _pywrap_tensorflow_internal.new_TF_Output()
#    1053         try:
# -> 1054             self.this.append(this)
#    1055         except Exception:
#    1056             self.this = this
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/pywrap_tensorflow_internal.py in <lambda>(self, name)
#    1038     __setattr__ = lambda self, name, value: _swig_setattr(self, TF_Output, name, value)
#    1039     __swig_getmethods__ = {}
# -> 1040     __getattr__ = lambda self, name: _swig_getattr(self, TF_Output, name)
#    1041     __repr__ = _swig_repr
#    1042     __swig_setmethods__["oper"] = _pywrap_tensorflow_internal.TF_Output_oper_set
#
# KeyboardInterrupt:

# %%
print(len(test_labels))
# Out:
# 993

# %%
with tf.Session() as sess:
  print(sess.run(loss, feed_dict={x: test_values, y: test_labels, keep_prob: dropout}))

# %%
files.download('predictions_wine.csv')

# %%
full_mat = []
for i in range(len(predicted)):
  full_mat.append([i, predicted[i][0]])

# %%
labels = ['Id', 'quality']
new_df = pd.DataFrame.from_records(full_mat, columns=labels)
new_df.to_csv('predictions_wine.csv',index=False)
#print(new_df.head(5))
files.download('predictions_wine.csv')

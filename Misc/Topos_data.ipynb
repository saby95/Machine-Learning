# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('incidents_NYC__final.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
latitude = build_data['LATITUDE'].values.tolist()
min(latitude)
# Out:
# 40.499031

# %%
max(longitude)
# Out:
# -73.70073599999998

# %%
longitude = build_data['LONGITUDE'].values.tolist()
min(longitude)
# Out:
# -74.254886

# %%
build_data = pd.read_csv('Buildings_data_final.csv')

# %%
roads_df = pd.read_csv('roads.csv')

# %%
build_data

# %%
roads_list = roads_df['ROAD NAME'].values.tolist()
on_roads = df['ON STREET NAME'].dropna().values.tolist()
cross_roads = df['CROSS STREET NAME'].dropna().values.tolist()
off_roads = df['OFF STREET NAME'].dropna().values.tolist()
inv = [0]*len(roads_list)

# %%
build_roads = build_data['Street Name'].dropna().values.tolist()

# %%
t_bin = []
rid_bin = []
buildings = []
incidents = []
for i in range(1,102):
  for j in range(0,len(dic)):
    t_bin.append(i)
    rid_bin.append(j)
    buildings.append(0)
    incidents.append(0)

# %%
o_r = df['ON STREET NAME'].values.tolist()
c_r = df['CROSS STREET NAME'].values.tolist()
of_r = df['OFF STREET NAME'].values.tolist()

# %%
r_bins = []
for i in range(len(o_r)):
  tmp = []
  if not(o_r[i] is of_r[0]):
    tmp.append(dic[o_r[i]])
  if not(c_r[i] is of_r[0]):
    tmp.append(dic[c_r[i]])
  if not(of_r[i] is of_r[0]):
    tmp.append(dic[of_r[i]])
  r_bins.append(tmp)

# %%
g = len(dic)
# Out:
# 124335

# %%
for i in range(len(r_bins)):
  for road in r_bins[i]:
    try:
      tmp = ((time_bins[i]-1)*g)+road
      incidents[tmp]+=1
      
    except IndexError:
      print(tmp)

# %%
cons_time_bins = build_data['TIME BIN'].values.tolist()

# %%
f = 0
for i in range(len(con_time_bins)):
  for bins in con_time_bins[i]:
    try:
      road = dic[build_roads[i]]
      tmp = ((bins-1)*g)+road
      buildings[tmp]+=1
      
    except IndexError:
      print(tmp)
    except KeyError:
      f+=1
f
# Out:
# 3125807

# %%
np.unique(build_data['Permit Status'].values.tolist())
# Out:
# array(['IN PROCESS', 'ISSUED', 'RE-ISSUED', 'nan'], dtype='<U10')

# %%
con_time_bins = []
for st in cons_time_bins:
    tmp = []
    st = st.replace('[','')
    st = st.replace(']','')
    sts = st.split(',')
    #tmp = list(map(int,sts))
    for s in sts:
      try:
        tmp.append(int(s))
      except ValueError:
        pass
    con_time_bins.append(tmp)

# %%
con_time_bins[0]
# Out:
# [87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99]

# %%
exp_month = build_data['EXP MONTH'].dropna().values.tolist()
exp_year = build_data['EXP YEAR'].dropna().values.tolist()

# %%
cons_time_bins = []
for i in range(len(start_month)):
  start_bin = ((start_year[i]-2012)*12)+start_month[i]
  end_bin = ((exp_year[i]-2012)*12)+exp_month[i]
  app_bins = []
  for bins in range(start_bin,end_bin+1):
    app_bins.append(bins)
  cons_time_bins.append(app_bins)

# %%
maxi = 0
g = 0
for i in range(len(cons_time_bins)):
  try:
    if maxi<max(cons_time_bins[i]):
      maxi = max(cons_time_bins[i])
  except ValueError:
    g+=1

# %%
maxi
# Out:
# 101

# %%
build_data['TIME BIN'] = cons_time_bins

# %%
len(long_bin1)
# Out:
# 494532

# %%
build_data = build_data[build_data['LATITUDE']>=lat_range[0]]

# %%
lat1 = build_data['LATITUDE'].dropna().values.tolist()

# %%
min(lat1)
# Out:
# 40.499031

# %%
max(build_lat_lon)
# Out:
# 396

# %%
_build_data['LAT_LONG_BIN'] = lat_long_bin1

# %%
df['LAT_LONG_BIN'] = lat_long_bin

# %%
i=0
dic={}

# %%
i=0
while(i<len(lat)):
  if lat[i] == 0.0:
    del lat[i]
  else:
    i+=1

# %%
new_df = pd.DataFrame()

# %%
new_df['TIME BIN'] = t_bin
new_df['ROAD_BIN'] = rid_bin
new_df['NO OF BUILDINGS IN WORK'] = buildings
new_df['NO OF INCIDENTS REPORTED'] = incidents

# %%
new_df = new_df[new_df['NO OF INCIDENTS REPORTED']!=0]

# %%
len(new_df)
# Out:
# 15079

# %%
max(build_lat_lon)
# Out:
# 396

# %%
build_lat_lon = build_data['LAT_LONG_BIN'].dropna().values.tolist()

# %%
exp_month = []
for st in exp_month_string:
  exp_month.append(int(st))

# %%
time_bin_master = []
lat_long_bin_master = []
buildings = []
incidents = []
for i in range(1,102):
  for j in range(1,397):
    time_bin_master.append(i)
    lat_long_bin_master.append(j)
    buildings.append(0)
    incidents.append(0)

# %%
len(buildings)
# Out:
# 39996

# %%
for i in range(len(time_bins)):
    try:
      tmp = ((time_bins[i]-1)*396)+(lat_long_bins[i]-1)
      incidents[tmp]+=1
      
    except IndexError:
      print(tmp)

# %%
for i in range(len(cons_time_bins)):
  for bins in cons_time_bins[i]:
    try:
      tmp = ((bins-1)*396)+(build_lat_lon[i]-1)
      buildings[tmp]+=1
      
    except IndexError:
      print(tmp)

# %%
build_data['EXP MONTH'] = exp_month
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2019 = df.loc[df['YEAR'] == 2019]

# %%
min(time_bins)
# Out:
# 7

# %%
lat_long_bins = df['LAT_LONG_BIN']

# %%
i=0
dic = {}

# %%
for road in off_roads:
  try:
    g = dic[road]
  except KeyError:
    dic[road] = i
    i+=1

# %%
dic['108 STREET']
# Out:
# 7802

# %%
rid = []
roads = []
for key, value in dic.items():
  rid.append(value)
  roads.append(key)

# %%
new_df = pd.DataFrame()
new_df['RID'] = rid
new_df['ROAD NAME'] = roads

# %%
new_df = new_df[new_df['NO OF BUILDINGS IN WORK']!=0]

# %%
len(new_df)
# Out:
# 71223

# %%
new_df.to_csv('buildings_incidents_roads.csv',index=False)

# %%
df = df.drop(l,axis=1)

# %%
df.to_csv('incidents_NYC_lat_long.csv',index=False)

# %%
build_data.to_csv('Buildings_data_lat_long.csv',index=False)

# %%
from google.colab import files

# %%
files.download('incidents.csv')

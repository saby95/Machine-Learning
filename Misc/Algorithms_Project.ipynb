# %% [markdown]
# # CSCE-629: Analysis of Algorithms - Project
#
# ##### Author - Shabarish Kumar Rajendra Prasad
#
# ## Creating the Graph Object
# The first step in the approach is that we need to model our Graph data-structure. I am using the defaultdict module from python's collections as a hashmap for adjacency lists of the vertices. The graph object also provides methods to insert edges, get neighbors and get edges of a particular vertex

# %%
import numpy as np
from collections import defaultdict, deque
import random
import time

# %%
class Graph:

  def __init__(self):

    #initialize adjacency list as a dictionary of lists
    self.adjList = defaultdict(list)

    #initialize neighbors as a dictionary of sets
    self.neighbor = defaultdict(set)

    #initialize edge list
    self.edgeList = []
  
  def InsertEdge(self, u, v, w):

    #prevent duplicates and add edge for u
    if v not in self.neighbor[u]:
      self.neighbor[u].add(v)
      self.adjList[u].append([v,w])
    
    #prevent duplicates and add edge for v
    if v not in self.neighbor[v]:
      self.neighbor[v].add(u)
      self.adjList[v].append([u,w])
    
    #append edge to edgeList
    self.edgeList.append([w,u,v])

  def getNeighbors(self, v):

    #From neighbors dictionary return the element
    return self.neighbor[v]

  def getEdges(self, v):
    
    #From adjacency list dictionary return the element
    return self.adjList[v]

  def getDegree(self, v):

    #The length of the adjacency list will the degree of the element
    return len(self.adjList[v])
  
  def getEdgeList(self):

    #return the edge list
    return self.edgeList

# %% [markdown]
# ## 1. Random Graph Generation
#
#
# ### 1.1 Sparse Graph
# The projects requires us to create two graphs, the first of which is a sparse graph. We first make sure we have a fully connceted graph and therefore we randomnly shuffle the numbers between 0-4999 and make edges between the adjacent vertices in the shuffled list. Then we go on and create the graph such that it has 15000 edges. Since there are 15000 undirected edges and 5000 vertices in our graph, the average degree of the vertices is exacty 6.

# %%
def generateSparseGraph():  
  
  #Initialize the Sparse Graph
  SparseGraph = Graph()

  #Making sure we have a fully-connected Graph
  #List all 5000 vertices and randomly shuffle the list
  stack = list(range(5000))
  random.shuffle(stack)

  #Insert edges between all the neighbors in the list
  previous = stack.pop()
  while(True):
    current = stack.pop()
    weight = random.randint(1,999)
    SparseGraph.InsertEdge(previous,current,weight)
    previous = current

    #break if the stack is empty
    if not stack:
      break

  #Create more edges so that the average degree of the vertices is 6
  for _ in range(10001):
    while(True):
      u = random.randint(0,4999)
      v = random.randint(0,4999)

      if u != v and v not in SparseGraph.getNeighbors(u):
        weight = random.randint(1,999)
        SparseGraph.InsertEdge(u,v,weight)
        break
      
      else:
        continue
  return SparseGraph

# %% [markdown]
# ### 1.2 Dense Graph
#
# Create the second Graph, which is the dense graph, in which every vertex is connected with 20% of the graph. We also make sure that the graph is fully-connected by following the steps followed for the sparse graph. Then we connect each vertex to about 20% of the graph.

# %%
def generateDenseGraph():
    
  #Initialize the Dense Graph
  DenseGraph = Graph()

  #Making sure we have a fully-connected Graph
  #List all 5000 vertices and randomly shuffle the list
  stack = list(range(5000))
  random.shuffle(stack)

  #Insert edges between all the neighbors in the list
  previous = stack.pop()
  while(True):
    current = stack.pop()
    weight = random.randint(1,999999)
    DenseGraph.InsertEdge(previous,current,weight)
    previous = current

    #break if the stack is empty
    if not stack:
      break

  available = list(range(5000))

  #Create more edges so that every vertex is connected to about  20% of the graph
  for u in range(5000):
    while(True):
      no_edges = len(DenseGraph.getNeighbors(u))

      #break if the vertex is connected to 20% of the graph
      if no_edges > 1000:
        break

      while(True):
        v = random.choice(available)

        if DenseGraph.getDegree(v)>=1025:
          available.remove(v)
          continue

        if u != v and v not in DenseGraph.getNeighbors(u):
          weight = random.randint(1,999999)
          DenseGraph.InsertEdge(u,v,weight)
          break
        
        else:
          continue
  return DenseGraph

# %% [markdown]
# ## 2. Heap Structure
#
# The next part of the project is to define a maximum heap structure. We have created a heap structure here which creates uses the first element in a tuple for comparison. Hence whenever we create a list to insert in the heap, we should make sure that the element to be comapred is in the index 0 (first element) of the tuple

# %%
class MaxHeap:

  def __init__(self):

    #initialize the array when the object gets initialized
    self.heap = []

  def push(self, value):

    #add the pushed value as the last element of the array
    self.heap.append(value)

    #Keep pushing the element above until it is lesser than its parent
    i = int(len(self.heap))-1
    while ((i>0) and (self.heap[i//2]<self.heap[i])):
      self.heap[i//2], self.heap[i] = self.heap[i], self.heap[i//2]
      i = i//2

  def pop(self):

    #Temporily store the max element
    ret = self.heap[0]

    #delete the element from the heap
    self.delete(0)

    #return element
    return ret

  def delete(self, i):
    #get length of the heap
    n = len(self.heap)

    #Check corner cases
    if n==1 and i == 0:
      self.heap.pop()

    else:
      #Swap the last element to the element to be replaced
      self.heap[i] = self.heap.pop()
      n = n-1

      #Shift up if applicable
      if (i>0) and (self.heap[i/2] < self.heap[i]):

        #Keep shifting until the heap is proper
        while ((i>0) and (self.heap[i/2] < self.heap[i])):
          self.heap[i/2], self.heap[i] = self.heap[i], self.heap[i/2]
          i = i/2
      
      #Else shift down
      else:

          #Keep shifting until the heap is proper
          while(((2*i < n) and (self.heap[2*i] > self.heap[i])) or 
                (((2*i)+1 < n) and (self.heap[(2*i)+1] > self.heap[i]))):
            
            #Check which child to shift up
            if ((2*i==n-1) or (self.heap[2*i] > self.heap[(2*i)+1])):
              self.heap[i], self.heap[2*i] = self.heap[2*i], self.heap[i]
              i = 2*i
            else:
              self.heap[i], self.heap[(2*i)+1] = self.heap[(2*i)+1], self.heap[i]
              i = (2*i)+1

# %% [markdown]
# ## 3. Routing algorithms
#
# ### 3.1 Dijkstra's Algorithm without Heap
#
# The code below implements Dijkstra's algorithm on a graph without using a heap structure for selecting the element from the fringe to add to the tree.

# %%
def Dijkstra_No_Heap(G, s, t):

  #record the start time
  start_time = time.time()
  s, t = s-1, t-1

  #initialize necessary variables
  status = ['unseen'] * 5000
  dad = [0] * 5000
  bw = [0] * 5000
  status[s] = 'intree'
  path = str(t+1)

  #start adding the neighbors of start to fringe
  for v, w in G.getEdges(s):
    status[v] = 'fringe'
    dad[v] = s
    bw[v] = w
  
  while(True):
    u, w = -1, 0

    #Check for the fringe with minimum bw
    for i in range(5000):
      if status[i] == 'fringe' and bw[i] > w:
        w = bw[i]
        u = i

    #Add vertex to tree
    status[u] = 'intree'

    #stop if target is found
    if u == t:
      #trace the path
      tmp = t
      while (tmp!=s):
        tmp = dad[tmp]
        path = str(tmp+1)+'->'+path
      #return the bw, path and time of execution
      return w, path, time.time()-start_time
    
    #Check all the neighbors of the vertex
    for v, w1 in G.getEdges(u):

      #Add all unseen vertices to fringe
      if status[v] == 'unseen':
        status[v] = 'fringe'
        dad[v] = u
        bw[v] = min(w,w1)

      #check the all the fringes if better bw is available
      elif status[v] == 'fringe' and min(w,w1) > bw[v]:
        dad[v] = u
        bw[v] = min(w,w1)

# %% [markdown]
# ### 3.2 Dijkstra's Algorithm with Heap
#
# The code below implements Dijkstra's algorithm on a graph using a heap structure for selecting the element from the fringe to add to the tree.

# %%
def Dijkstra_Heap(G, s, t):

  #record the start time
  start_time = time.time()
  s, t = s-1, t-1

  #initialize necessary variables
  status = ['unseen'] * 5000
  dad = [0] * 5000
  bw = [0] * 5000
  status[s] = 'intree'
  path = str(t+1)
  H = MaxHeap()

  #start adding the neighbors of start to fringe
  for v, w in G.getEdges(s):
    status[v] = 'fringe'
    dad[v] = s
    bw[v] = w
    H.push([w,v])
  
  while(True):

    #Pop the element from heap
    w, u = H.pop()

    #Check if vertex already in tree
    if status[u] == 'intree':
      continue

    #Add vertex to tree
    status[u] = 'intree'

    #stop if target is found
    if u == t:
      #trace the path
      tmp = t
      while (tmp!=s):
        tmp = dad[tmp]
        path = str(tmp+1)+'->'+path
      #return the bw, path and time of execution
      return w, path, time.time()-start_time
    
    #Check all the neighbors of the vertex
    for v, w1 in G.getEdges(u):

      #Add all unseen vertices to fringe
      if status[v] == 'unseen':
        status[v] = 'fringe'
        dad[v] = u
        bw[v] = min(w,w1)
        H.push([min(w,w1),v])

      #check the all the fringes if better bw is available
      elif status[v] == 'fringe' and min(w,w1) > bw[v]:
        dad[v] = u
        bw[v] = min(w,w1)
        H.push([min(w,w1),v])

# %% [markdown]
# ### 3.3 Kruskal's algorithm
#
# The code below implements Kruskal's algorithm to build a maximum spanning tree and to find the maximum bandwidth path from the tree.

# %%
class UnionFind:

  #initialize the dad and wt of tree as dictionaries
  def __init__(self):
        self.wt = {}
        self.dad = {}

  #define getitem
  def __getitem__(self, object):
        #if item is not in dad, add item and return
        if object not in self.dad:
            self.dad[object] = object
            self.wt[object] = 1
            return object

        path = [object]
        root = self.dad[object]
        #trace all ancestors
        while root != path[-1]:
            path.append(root)
            root = self.dad[root]
        #assign dad of all ancestors to be root
        for ancestor in path:
            self.dad[ancestor] = root
        #return root
        return root
        
  def __iter__(self):
        return iter(self.dad)
      
  def union(self, *objects):
        roots = [self[x] for x in objects]
        heaviest = max([(self.wt[r],r) for r in roots])[1]
        for r in roots:
            #find the heaviest tree and add the other tree
            if r != heaviest:
                self.wt[heaviest] += self.wt[r]
                self.dad[r] = heaviest

# %%
#define the heapify function
def heapify(arr, n, i): 
    smallest = i  
    l = 2 * i + 1     
    r = 2 * i + 2      
    if l < n and arr[i] > arr[l]: 
        smallest = l 
    if r < n and arr[smallest] > arr[r]: 
        smallest = r 
    if smallest != i: 
        arr[i],arr[smallest] = arr[smallest],arr[i] 
        heapify(arr, n, smallest)

#define the heapsort function
def heapSort(arr): 
    n = len(arr) 
    for i in range(int(n/2)-1, -1, -1): 
        heapify(arr, n, i) 
    for i in range(n-1, 0, -1): 
        arr[i], arr[0] = arr[0], arr[i] 
        heapify(arr, i, 0)

# %%
def Kruskal(G):

  #record the start time
  start_time = time.time()
  global visited
  visited = set()

  #get the list of edges
  edges = G.getEdgeList()

  #sort the edges using heapsort
  heapSort(edges)

  #initialize the unionfind object and a new graph for the spanning tree
  subtrees = UnionFind()
  T = Graph()

  #iterate all edges in edgelist
  for w, u, v in edges:

    #check if the two vertices does not belong to the same tree
    if subtrees[u] != subtrees[v]:
      T.InsertEdge(u, v, w)
      subtrees.union(u, v)

  #return the spanning tree
  return T, time.time()-start_time

# %%
#define the BFS algorithm to search for the route in Spanning tree
def bfs(G, s, t):

  start_time = time.time()
  s, t = s-1, t-1

  #record the start time
  if s == t:
    return 0, str(s+1)
  
  path = str(s+1)
  Q = deque()
  visited = set([s])
  #add edges of start vertex
  for v, w in G.getEdges(s):
    if v not in visited:
      Q.append([v,w,path+'->'+str(v+1)])
      visited.add(v)
  
  while(True):
    v, w, path = Q.popleft()

    #return if target is found
    if v == t:
      return w, path, time.time()-start_time
    
    for v1, w1 in G.getEdges(v):
      if v1 not in visited:
        Q.append([v1,min(w,w1),path+'->'+str(v1+1)])
        visited.add(v1)

# %% [markdown]
# ## 4. Testing
#
# I am randomly generating sources and targets from a pool of 5000 values and running the same set of sources and targets on 5 versions of Sparse Graphs and 5 different versions of Dense Graphs.

# %%
pool = list(range(1,5001))
sources = []
targets = []

for _ in range(5):
  source = random.choice(pool)
  pool.remove(source)
  target = random.choice(pool)
  pool.remove(target)
  sources.append(source)
  targets.append(target)

testSet = list(zip(sources,targets))

# %%
SparseGraphs = []
DenseGraphs = []
for i in range(5):
  SparseGraphs.append(generateSparseGraph())
  DenseGraphs.append(generateDenseGraph())

# %% [markdown]
# ### Testing Dijkstra's Algorithm without Heap on Sparse Graph

# %%
bw1 = [[0]*5]*5
path1 = [['']*5]*5
time1 = [[0 for _ in range(5)] for _ in range(5)]
i = 0
for SparseGraph in SparseGraphs:
  j = 0
  print("Results for Sparse Graph ",i+1,'\n')
  for source, target in testSet:
    bw1[i][j], path1[i][j], time1[i][j] = Dijkstra_No_Heap(SparseGraph, source, target)
    print("Source: ",source,"\t"+"Target: ",target)
    print("Maximum Bandwidth: ", bw1[i][j])
    print("Path Followed by algotithm: "+path1[i][j])
    print("Time taken by algorithm: "+"%.3f seconds"%time1[i][j],'\n')
    j+=1
  print('\n\n\n')
  i+=1
# Out:
# Results for Sparse Graph  1
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  730
# Path Followed by algotithm: 4747->3854->3042->379->258->2647->1553->945->212->2225->3215->2231->136->352->2850->482->43->1157->2207->367->2702->832->2678->2750->2939->2896->1792->2780->803->788->1297->835->3301->3->1625->2190->512->573->3374->982->3305->1400->1612->979->2023->1785->3365->2659->1596->676->3725->3277->4051
# Time taken by algorithm: 0.649 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  589
# Path Followed by algotithm: 4942->1264->2270->3566->2096->3518->4323->2494->569->502->857->376->2396->993->458->205->1512->1559->881->245->1686->849->1044->783->43->1157->1251->3742->2967->4015
# Time taken by algorithm: 1.159 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  307
# Path Followed by algotithm: 3262->4450->529->1350->457->1304->346->1144->720->1082->633->642->1343->195->487->1227->860->1402->165->1128->1362->1364->1089->520->31->698->764->119->910->584->2704->1484->2996->2191
# Time taken by algorithm: 0.901 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  516
# Path Followed by algotithm: 3076->901->3502->1196->750->4458->839->462->2134->4346->4441->43->1278->46->1799->1253->2945->4393->4253->4265->3288->4835->1029->1526->3020->3494
# Time taken by algorithm: 1.644 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  678
# Path Followed by algotithm: 2184->678->114->3211->492->2360->417->1924->3726->1732->2843->1869->3791->420->434
# Time taken by algorithm: 0.712 seconds
#
#
#
#
#
# Results for Sparse Graph  2
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  610
# Path Followed by algotithm: 4747->1625->2993->195->3817->2282->2909->4869->504->2951->125->4464->3055->2314->3813->917->1418->1369->308->2902->4951->2483->3340->1053->2345->4999->988->4457->2035->1927->1816->607->2761->4984->1194->3172->131->991->617->2140->2034->1199->1435->3008->525->4866->4011->436->2820->3133->531->3885->1530->2870->2841->2396->4306->235->578->3935->2093->594->4877->3405->2580->2200->4051
# Time taken by algorithm: 1.561 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  436
# Path Followed by algotithm: 4942->2148->1901->1624->1961->954->240->1486->1676->949->337->1567->2052->1134->1778->329->1190->1677->968->1455->1585->1769->1176->1707->226->1048->1747->718->120->1502->865->1578->488->725->1434->472->1369->1418->218->1127->1254->980->1335->953->663->512->932->624->508->271->1148->822->584->116->1662->287->4015
# Time taken by algorithm: 1.284 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  790
# Path Followed by algotithm: 3262->4251->23->4567->175->495->1295->121->2441->3952->639->1635->1715->3360->3501->3211->631->2918->2097->1756->4015->3939->617->2140->2034->820->1223->3907->3879->4358->4277->3726->3180->1816->1927->2167->112->3461->3803->69->3414->1328->2920->849->273->3558->2135->2770->2511->3875->4138->4212->2191
# Time taken by algorithm: 0.194 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  824
# Path Followed by algotithm: 3076->1961->2124->373->1599->820->2034->2140->617->991->131->3172->1194->4984->2761->607->1816->1927->2035->4457->988->4999->2345->1053->3340->3193->1732->4679->386->3494
# Time taken by algorithm: 0.207 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  622
# Path Followed by algotithm: 2184->4473->950->584->822->3585->3033->4489->3683->3334->4330->2588->301->2804->3397->4305->4971->3287->58->2097->2918->631->3211->3501->3360->1715->1635->639->239->4340->3260->4045->1986->3561->434
# Time taken by algorithm: 1.500 seconds
#
#
#
#
#
# Results for Sparse Graph  3
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  740
# Path Followed by algotithm: 4747->4137->4073->3522->1690->2124->225->809->91->4328->1031->1939->3145->1426->1290->2390->4077->4809->4051
# Time taken by algorithm: 1.099 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  732
# Path Followed by algotithm: 4942->1687->343->88->4125->1233->1102->2945->2439->3606->1999->2420->214->3511->1680->1001->2294->3559->1695->3552->83->3108->3611->561->2259->310->2742->510->587->1792->3023->1306->2481->2632->3240->3662->500->604->1014->816->4015
# Time taken by algorithm: 0.501 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  526
# Path Followed by algotithm: 3262->3288->4498->783->984->510->587->1792->3023->1306->2481->2632->3240->2775->1975->314->38->1222->1707->4861->3772->64->488->2676->1829->4948->678->2032->611->4634->1992->3637->1932->739->883->4540->4194->3481->1467->3552->83->3108->3611->561->3115->4911->164->201->717->3629->1413->2191
# Time taken by algorithm: 1.645 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  749
# Path Followed by algotithm: 3076->2241->3807->3952->1071->159->4947->4845->2049->2525->3621->2515->1307->2488->2965->1208->1690->2124->225->2420->214->3511->1680->1001->2294->3559->1695->3552->83->3108->3611->33->3034->2114->1166->1984->3573->2746->590->609->346->2869->1735->936->471->3211->1378->1797->3111->1454->641->3622->543->296->1295->673->3214->2900->1016->3567->1898->693->3153->3342->60->865->2856->529->2620->432->398->222->1840->53->1873->1299->170->834->756->2949->2413->1076->2689->4048->2988->1728->3494
# Time taken by algorithm: 0.420 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  499
# Path Followed by algotithm: 2184->3769->4211->1404->2739->1486->1096->4121->3866->708->2233->2749->1863->778->1034->1900->146->3285->1921->4172->1554->3842->628->434
# Time taken by algorithm: 1.686 seconds
#
#
#
#
#
# Results for Sparse Graph  4
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  661
# Path Followed by algotithm: 4747->3181->3883->2716->1513->1945->2857->1948->961->1672->3051->2759->3737->2925->855->1993->3338->1583->1236->3451->2549->1048->641->902->454->2013->166->2136->950->1350->874->735->1905->453->104->2754->4132->2790->893->3554->4051
# Time taken by algorithm: 1.489 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  631
# Path Followed by algotithm: 4942->4096->2537->2636->2522->2205->1993->855->2925->353->1221->330->2621->2191->501->2040->2052->543->1134->52->1908->2188->562->862->2531->2498->553->2365->2260->1821->2320->1872->2218->1308->2059->1139->4015
# Time taken by algorithm: 1.078 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  730
# Path Followed by algotithm: 3262->1672->961->1948->774->1903->2253->846->1175->581->635->3138->1761->1658->807->1866->202->1326->965->1466->2690->1103->3034->755->1694->1166->2919->2559->3505->1298->630->318->2982->2378->2678->3226->2964->3343->3736->3036->655->2201->390->1850->1632->2507->875->2191
# Time taken by algorithm: 0.238 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  775
# Path Followed by algotithm: 3076->1944->4138->3279->2266->1092->4817->1581->3622->2112->305->1921->3551->4067->3816->961->1672->3051->2759->4400->2896->1563->1241->2256->4352->958->770->1070->3971->1765->1899->4061->829->2905->3188->2592->256->381->4039->4106->4057->2013->166->2136->2436->4917->4923->2521->4974->3559->2497->582->47->3438->4885->781->4465->666->379->4650->2769->4287->2041->559->691->3539->434->2250->592->4681->361->2002->1000->4514->3494
# Time taken by algorithm: 0.767 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  619
# Path Followed by algotithm: 2184->4746->1634->1153->1761->1658->2260->2365->553->2498->2531->862->562->2188->1908->676->1988->592->2250->434
# Time taken by algorithm: 0.088 seconds
#
#
#
#
#
# Results for Sparse Graph  5
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  608
# Path Followed by algotithm: 4747->2504->499->878->3626->1870->71->2796->1536->4141->1695->1538->1270->427->1236->456->75->1848->3840->1775->2150->3189->200->3352->2832->289->3910->829->2346->3152->3253->51->1468->1567->971->1980->3310->3806->420->992->1664->3492->476->354->1461->3979->2186->623->4051
# Time taken by algorithm: 1.562 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  742
# Path Followed by algotithm: 4942->3157->1584->2298->4941->1418->372->3438->4151->3569->1534->3833->791->1217->3122->2943->3082->2975->1444->3187->1164->2749->1245->963->1633->2412->1605->1462->2048->1922->2204->2164->2511->125->3312->3064->2647->2484->834->1166->2369->4015
# Time taken by algorithm: 0.498 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  680
# Path Followed by algotithm: 3262->4054->1175->1547->1463->2283->3448->3060->808->1843->2482->120->404->1800->799->368->1497->2817->333->2225->2488->872->427->1270->861->1922->2204->572->2702->1488->2261->2040->1862->1530->1112->567->1320->2864->15->2989->929->200->3189->2459->322->67->1136->3260->2636->38->2297->3224->2161->876->4222->868->4227->2191
# Time taken by algorithm: 1.017 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  592
# Path Followed by algotithm: 3076->924->2035->3310->1980->971->1567->1468->1975->594->3544->156->3294->3373->2682->3117->466->1409->1685->2334->1325->2080->1538->1270->861->1922->2204->572->2702->1488->2261->2040->1862->1530->1112->567->1320->2864->15->2989->929->200->3352->1773->1324->3506->526->1884->2851->1846->907->1138->2212->2328->1161->4600->1256->786->1677->4421->2136->736->614->4088->1198->3494
# Time taken by algorithm: 1.592 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  766
# Path Followed by algotithm: 2184->3191->3696->4380->599->4238->579->4409->1898->1846->907->1138->1109->3854->3839->1057->2449->1674->2752->3259->1842->3870->3229->558->1212->1518->2380->2007->588->1557->225->2555->3209->1048->675->2801->2346->3152->3253->51->1468->1567->971->1980->4011->2584->4387->1359->434
# Time taken by algorithm: 0.543 seconds

# %% [markdown]
# ### Testing Dijkstra's Algorithm with Heap on Sparse Graph

# %%
bw2 = [[0]*5]*5
path2 = [['']*5]*5
time2 = [[0 for _ in range(5)] for _ in range(5)]
i = 0
for SparseGraph in SparseGraphs:
  j = 0
  print("Results for Sparse Graph ",i+1,'\n')
  for source, target in testSet:
    bw2[i][j], path2[i][j], time2[i][j] = Dijkstra_Heap(SparseGraph, source, target)
    print("Source: ",source,"\t"+"Target: ",target)
    print("Maximum Bandwidth: ", bw2[i][j])
    print("Path Followed by algotithm: "+path2[i][j])
    print("Time taken by algorithm: "+"%.3f seconds"%time2[i][j],'\n')
    j+=1
  print('\n\n\n')
  i+=1
# Out:
# Results for Sparse Graph  1
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  730
# Path Followed by algotithm: 4747->3854->4400->4889->4732->3862->4140->1576->2768->2651->4526->4714->3664->1791->2056->1898->1582->3350->3378->4668->2806->4871->4382->3978->2434->1801->4051
# Time taken by algorithm: 0.021 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  589
# Path Followed by algotithm: 4942->1264->2270->3566->2096->3518->4323->4467->3893->3795->4125->3823->2933->4450->4679->4812->4632->4688->3698->3292->3920->3930->4301->3927->3053->4199->3548->3754->3376->4680->2945->3247->4348->2959->4039->4222->4076->3596->2765->3922->2800->4477->4001->1597->4497->4405->4368->1816->4015
# Time taken by algorithm: 0.056 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  307
# Path Followed by algotithm: 3262->4450->4679->4812->4632->3558->3853->3497->4656->4868->4121->4143->3925->4270->4073->3922->4762->4647->4500->4395->4001->4477->3960->4323->4426->3907->4434->3873->4933->4813->4393->4253->3995->3561->4769->2191
# Time taken by algorithm: 0.051 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  516
# Path Followed by algotithm: 3076->901->3502->1196->750->4458->1179->4309->4786->843->1195->4894->3995->4253->4265->3288->4835->1029->1526->3020->3494
# Time taken by algorithm: 0.126 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  678
# Path Followed by algotithm: 2184->678->114->4812->4632->3599->4220->4965->1819->4429->2869->3585->1738->3123->1905->3771->3958->2468->2875->3658->2195->3480->4859->3292->3920->3930->4301->3927->3053->4199->2416->2032->2348->3713->2455->2398->4149->4040->2644->4699->2058->4915->2968->3609->3427->1867->3616->4587->3915->1862->2387->1769->2673->1998->4533->3894->420->434
# Time taken by algorithm: 0.071 seconds
#
#
#
#
#
# Results for Sparse Graph  2
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  610
# Path Followed by algotithm: 4747->1625->2993->195->3817->2282->2909->4869->504->2951->125->4464->3055->2314->3813->917->1418->1369->308->2902->4951->2483->3340->1053->2345->4999->988->4457->2035->1927->1816->607->2761->4984->1194->3172->131->991->617->2140->2034->1199->1435->3008->525->4866->4011->436->2820->3133->531->3885->1530->2870->2841->2396->4306->235->578->3935->2093->594->4877->3405->2580->2200->4051
# Time taken by algorithm: 0.102 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  436
# Path Followed by algotithm: 4942->2148->1901->4066->1721->2778->4716->3898->3065->4973->4780->4407->4832->3945->4557->3273->4137->4977->4813->4011->4193->3946->4672->4169->3814->4863->3919->3646->3774->4492->3871->4240->3908->4803->3836->4485->4070->3556->3880->3805->4662->3465->4691->3997->3164->4041->3269->3891->3128->3244->4821->3737->3169->4560->4874->4026->4733->4568->4396->4943->4990->3450->3327->4660->3533->4314->3781->4841->4050->3435->3935->3190->4209->3733->4544->4015
# Time taken by algorithm: 0.016 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  790
# Path Followed by algotithm: 3262->4251->23->4567->175->495->1295->121->2441->3952->639->1635->1715->3360->3501->3211->631->2918->2097->1756->4015->3939->617->2140->2034->820->1223->3907->3879->4358->4277->3726->3180->1816->1927->2035->4457->988->4999->2345->1053->3340->3193->1732->4679->3035->1905->2640->695->2364->3086->3117->4588->4212->2191
# Time taken by algorithm: 0.013 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  824
# Path Followed by algotithm: 3076->1961->2124->373->1599->820->2034->2140->617->991->131->3172->1194->4984->2761->607->1816->1927->2035->4457->988->4999->2345->1053->3340->3193->1732->4679->386->3494
# Time taken by algorithm: 0.019 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  622
# Path Followed by algotithm: 2184->4473->950->584->822->3585->3033->4489->3683->3334->4330->2588->301->2804->3397->4305->4971->3287->58->2097->2918->631->3211->3501->3360->1715->1635->639->239->4340->3260->4045->1986->3561->434
# Time taken by algorithm: 0.102 seconds
#
#
#
#
#
# Results for Sparse Graph  3
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  740
# Path Followed by algotithm: 4747->4137->4073->3522->1690->2124->225->809->91->4328->1031->1939->3145->1426->1290->2390->4077->4809->4051
# Time taken by algorithm: 0.081 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  732
# Path Followed by algotithm: 4942->1687->343->4580->4815->1957->725->3232->2273->1307->2515->3621->2525->2049->4845->2399->3806->4517->1684->2689->3738->3157->3275->2586->2388->2128->2483->2490->2039->3372->2607->3514->4349->2178->2428->4729->4894->4787->3492->2310->4615->4903->4975->4792->4786->4264->2318->1517->4036->2258->3633->3438->4570->3748->2296->3825->4234->4078->3838->1014->816->4015
# Time taken by algorithm: 0.046 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  526
# Path Followed by algotithm: 3262->3288->4498->783->984->510->587->1792->3023->1306->2481->2632->3240->2775->1975->314->38->1222->1707->4861->3772->64->488->2676->1829->4948->678->2032->611->4634->1992->3637->1932->739->883->4540->4194->3481->1467->3552->83->3108->3611->561->3115->4911->164->201->717->3629->1413->2191
# Time taken by algorithm: 0.117 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  749
# Path Followed by algotithm: 3076->2241->3807->3952->1071->159->4947->4845->2399->3806->4517->1684->2689->4048->2988->1728->3494
# Time taken by algorithm: 0.006 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  499
# Path Followed by algotithm: 2184->3769->4211->1404->2739->1486->1096->4121->3866->708->2233->2749->1863->778->2976->4321->2582->3023->1792->2240->2568->4756->1014->3838->4078->4234->4225->3030->1539->4043->2966->1441->786->3087->1966->3342->3153->3547->2329->4136->1768->1728->2988->4048->4319->3477->4325->2021->4744->3900->4623->1629->3641->2720->4176->1855->752->3589->3285->1921->4172->1554->3842->628->434
# Time taken by algorithm: 0.141 seconds
#
#
#
#
#
# Results for Sparse Graph  4
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  661
# Path Followed by algotithm: 4747->3181->3883->3777->4998->4437->2027->4923->2521->4974->3559->2497->1506->1422->4504->3841->3121->898->1032->4542->2192->4709->922->1445->2754->4132->2790->893->3554->4051
# Time taken by algorithm: 0.092 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  631
# Path Followed by algotithm: 4942->4096->2537->3433->4501->2865->3110->3437->3093->4005->2319->2147->3771->2321->4105->4095->4118->4100->4693->4861->4055->4641->3531->3047->4644->2700->3418->4763->2771->4368->3957->3801->4014->2822->3052->4098->3777->4998->4437->2027->3435->4228->2277->4874->2059->1139->4015
# Time taken by algorithm: 0.064 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  730
# Path Followed by algotithm: 3262->1672->3051->4806->4618->2510->4242->4329->2136->2436->4917->4923->2027->3435->4228->1794->3634->4378->2360->4383->3831->4165->4369->2621->2191
# Time taken by algorithm: 0.015 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  775
# Path Followed by algotithm: 3076->1944->4138->3279->2266->1092->4817->1581->3622->2112->305->1921->3551->4067->3816->961->1672->3051->2759->4400->2896->1563->1241->2256->4352->958->770->1070->3971->1765->1899->4061->829->4546->2593->2354->3788->1243->4988->2436->4917->4923->2521->4974->3559->2497->582->47->3438->4885->781->4465->666->379->4650->2769->4287->2041->559->691->3539->434->2250->592->4681->361->2002->1000->4514->3494
# Time taken by algorithm: 0.062 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  619
# Path Followed by algotithm: 2184->4746->1634->3851->3276->2966->3108->4806->3051->2759->3737->2925->4960->3195->3010->3580->4278->3555->3208->4470->3036->3736->3343->2964->3226->4063->4795->2581->4466->3460->4309->3995->3636->3269->4346->4422->4703->4302->4306->4549->3777->4098->3052->2822->4014->3801->3957->4368->2771->4151->4411->4477->2650->2459->4880->3539->434
# Time taken by algorithm: 0.082 seconds
#
#
#
#
#
# Results for Sparse Graph  5
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  608
# Path Followed by algotithm: 4747->2504->499->878->3626->1870->71->2796->1536->4141->2903->2564->467->1083->3933->3402->1481->2094->4781->2665->2233->3581->1560->4245->1770->1567->971->1980->4011->4218->4936->3182->3764->1927->3822->4331->4428->4058->3133->3990->1123->3639->4628->1796->2059->1173->3618->1510->2837->3058->2186->623->4051
# Time taken by algorithm: 0.111 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  742
# Path Followed by algotithm: 4942->3157->1584->2298->3646->709->3679->1335->4145->4964->2584->4011->4218->4936->2894->2674->1710->4606->4855->4616->3287->2331->4015
# Time taken by algorithm: 0.006 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  680
# Path Followed by algotithm: 3262->4054->1175->1547->1463->2283->3448->3450->2124->2167->2734->2071->3054->3592->2201->4777->2652->3399->3553->3246->3728->1922->2204->2164->4810->4285->1124->3460->4222->868->4227->2191
# Time taken by algorithm: 0.064 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  592
# Path Followed by algotithm: 3076->924->2035->3310->1980->4011->2584->2611->2848->1737->4962->4970->3470->3870->1842->3259->4578->1410->1477->3197->4963->4600->1256->786->1677->4421->2136->736->614->4088->1198->3494
# Time taken by algorithm: 0.106 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  766
# Path Followed by algotithm: 2184->3191->3696->4380->599->4238->579->4409->3632->3244->2446->4303->1805->3471->2597->3786->4174->4694->1020->3058->2837->1510->3618->1173->2059->1796->4628->3639->1123->3990->3133->4058->4428->4331->3822->1927->3764->3182->4936->4218->4011->2584->4387->1359->434
# Time taken by algorithm: 0.037 seconds

# %% [markdown]
# ### Testing Kruskal's Algorithm on Sparse Graph

# %%
bw3 = [[0]*5]*5
path3 = [['']*5]*5
time3 = [[0 for _ in range(5)] for _ in range(5)]
timeG1 = [0 for _ in range(5)]
i = 0
for SparseGraph in SparseGraphs:
  j = 0
  T, timeG1[i] = Kruskal(SparseGraph)
  print("Results for Sparse Graph ",i+1,'\n')
  for source, target in testSet:
    bw3[i][j], path3[i][j], time3[i][j] = bfs(T,source,target)
    print("Source: ",source,"\t"+"Target: ",target)
    print("Maximum Bandwidth: ", bw3[i][j])
    print("Path Followed by algotithm: "+path3[i][j])
    print("Time taken by algorithm: "+"%.3f seconds"%(timeG1[i]+time3[i][j]),'\n')
    j+=1
  print('\n\n\n')
  i+=1
# Out:
# Results for Sparse Graph  1
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  730
# Path Followed by algotithm: 4747->3854->3042->379->4156->4125->4664->4820->2381->2901->662->2499->2238->470->2388->1535->3099->1007->4466->2213->3177->2240->3751->4245->834->2801->4802->4564->411->2167->756->3468->3445->4658->3628->2105->3212->3451->4460->2720->4467->4323->4426->3580->3526->853->3283->259->2597->310->3495->4639->1875->1035->3034->4406->3128->4714->3664->1791->2056->2945->4680->3564->4791->2850->352->136->2542->1867->3427->3609->1212->3414->2275->1126->3616->4587->3915->1859->1531->2419->3401->3586->2518->3869->3365->2659->1596->676->3725->3277->4051
# Time taken by algorithm: 0.213 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  589
# Path Followed by algotithm: 4942->1264->2270->3566->2096->3518->4323->4467->2720->4460->3451->3212->2105->3628->4658->3445->3468->756->2167->411->4564->4802->2801->834->909->4244->1527->3653->3556->336->3396->4559->2967->4015
# Time taken by algorithm: 0.207 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  307
# Path Followed by algotithm: 3262->4450->529->1350->3573->270->2330->1445->889->3594->814->151->3890->122->1890->835->4995->4842->3242->4864->16->3123->1738->4750->171->1001->1898->2056->2945->4680->3564->4791->2850->482->43->1157->3651->4369->1509->3796->2990->3844->2481->4848->2334->725->2803->4810->2740->1101->4711->4769->2191
# Time taken by algorithm: 0.210 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  516
# Path Followed by algotithm: 3076->901->3502->1196->750->4458->839->462->2134->4346->4441->43->482->2850->352->136->2542->1867->3427->3609->1212->3414->2275->1126->3616->4587->3915->1859->1531->2419->3401->3586->2518->4465->2501->3009->142->2417->4717->2509->1692->3288->4835->1029->1526->3020->3494
# Time taken by algorithm: 0.212 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  678
# Path Followed by algotithm: 2184->678->114->4417->3036->411->2167->756->3468->3445->4658->3628->2105->3212->3451->4460->2720->4467->4323->4426->3580->3526->853->3283->259->2597->310->3495->4639->1875->1035->3034->4406->3128->4714->3664->1791->2056->2945->4680->3564->4791->2850->352->136->2542->1867->3427->3609->1212->3414->2275->1126->3616->4587->3915->1859->1531->2419->3401->3586->2518->4465->2501->3009->142->2417->4717->1726->4432->3367->476->282->836->1921->740->4926->2661->1961->4615->2415->3053->3927->4301->3930->898->4696->3270->2421->4442->4010->2346->913->1784->3104->2023->979->1612->1400->3305->982->3374->2449->4249->2047->2061->1185->3505->2577->934->1831->1707->4076->3596->618->1399->2260->2958->2012->389->2889->3894->420->434
# Time taken by algorithm: 0.215 seconds
#
#
#
#
#
# Results for Sparse Graph  2
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  610
# Path Followed by algotithm: 4747->1625->2993->195->3817->2282->2909->4869->504->2951->125->4464->3055->2314->3813->917->1418->1369->308->2902->4951->2483->3340->1053->2345->4999->988->4457->2035->1927->1816->607->2761->4984->1194->3172->131->991->617->2140->2034->1199->1435->3008->525->4866->4011->436->2820->3133->531->3885->1530->2870->2841->2396->4306->235->578->3935->2093->594->4877->3405->2580->2200->4051
# Time taken by algorithm: 0.198 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  436
# Path Followed by algotithm: 4942->2148->1901->1719->2453->271->508->3013->4334->970->283->4311->4440->1606->1483->1665->1600->2310->4999->988->4457->2035->1927->1816->607->2761->4984->1194->3172->131->991->617->3939->4015
# Time taken by algorithm: 0.192 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  790
# Path Followed by algotithm: 3262->4251->23->4567->175->495->1295->121->2441->3952->639->1635->1715->3360->3501->3211->631->2918->2097->1756->4015->3939->617->991->131->3172->1194->4984->2761->607->1816->1927->2035->4457->988->4999->2345->1053->3340->3193->1732->4679->3035->1905->2640->695->2364->3086->3117->4588->4212->2191
# Time taken by algorithm: 0.199 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  824
# Path Followed by algotithm: 3076->1961->2124->373->1599->820->2034->2140->617->991->131->3172->1194->4984->2761->607->1816->1927->2035->4457->988->4999->2345->1053->3340->3193->1732->4679->386->3494
# Time taken by algorithm: 0.194 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  622
# Path Followed by algotithm: 2184->4473->950->584->822->3585->3033->4489->3683->3334->4330->2588->301->2804->3397->4305->4971->3287->58->2097->2918->631->3211->3501->3360->1715->1635->639->239->4340->3260->4045->1986->3561->434
# Time taken by algorithm: 0.193 seconds
#
#
#
#
#
# Results for Sparse Graph  3
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  740
# Path Followed by algotithm: 4747->4137->4073->3522->1690->2124->225->809->91->4328->1031->1939->3145->1426->1290->2390->4077->4809->4051
# Time taken by algorithm: 0.187 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  732
# Path Followed by algotithm: 4942->1687->343->88->1121->4815->1957->725->4199->4499->152->3663->752->3589->2510->1195->3772->4861->1707->1222->38->314->1975->2775->3240->3662->500->604->1014->816->4015
# Time taken by algorithm: 0.188 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  526
# Path Followed by algotithm: 3262->3288->4498->783->984->510->587->1792->3023->1306->2481->2632->3240->2775->1975->314->38->1222->1707->4861->3772->1195->2510->3589->3285->146->1900->1034->778->1863->2749->2233->708->169->3593->3626->3390->410->1816->717->3629->1413->2191
# Time taken by algorithm: 0.193 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  749
# Path Followed by algotithm: 3076->2241->3807->3952->1071->159->4947->4845->2399->3081->74->2145->4194->4540->883->739->1932->559->4483->3547->2329->4136->1768->1728->3494
# Time taken by algorithm: 0.187 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  499
# Path Followed by algotithm: 2184->3769->4211->1404->2739->1486->1096->4121->3866->708->2233->2749->1863->778->1034->1900->146->3285->3589->2510->1195->3772->64->488->2676->1829->4948->678->2032->611->4634->1992->3637->1932->559->4483->3547->3153->3342->1966->3649->4277->2983->3211->471->936->4397->742->3455->3532->4290->594->4464->1332->4839->4969->564->4220->3837->163->3450->4855->1616->4124->53->1873->1299->1554->3842->628->434
# Time taken by algorithm: 0.196 seconds
#
#
#
#
#
# Results for Sparse Graph  4
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  661
# Path Followed by algotithm: 4747->3181->3883->3777->4998->4437->2027->4923->2521->4974->3559->2497->582->47->3438->4885->781->4465->2662->437->1024->4811->372->113->1075->2664->1625->2342->3419->1761->3138->635->581->1175->1833->1219->170->4542->2192->4709->922->1445->2754->4132->2790->893->3554->4051
# Time taken by algorithm: 0.203 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  631
# Path Followed by algotithm: 4942->4096->2537->3433->4501->46->4001->3353->4629->686->1193->1291->4894->2135->2855->1734->1876->527->2014->2155->648->1308->2059->1139->4015
# Time taken by algorithm: 0.194 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  730
# Path Followed by algotithm: 3262->1672->3051->2759->4400->2896->1563->1241->2256->4352->958->770->1070->3971->1765->1899->2842->4078->3065->4134->2357->4264->1667->3616->4778->2242->104->453->1905->735->874->1350->950->2136->2436->4917->4923->2521->4974->3559->2497->582->47->3438->4885->781->4465->2662->437->1024->4811->372->113->1075->2664->4958->1389->3215->238->4165->4369->2621->2191
# Time taken by algorithm: 0.201 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  775
# Path Followed by algotithm: 3076->1944->4138->3279->2266->1092->4817->1581->3622->2112->305->1921->3551->4067->3816->961->1672->3051->2759->4400->2896->1563->1241->2256->4352->958->770->1070->3971->1765->1899->2842->4078->3065->4134->2357->4264->1667->3616->4778->2242->104->453->1905->735->874->1350->950->2136->2436->4917->4923->2521->4974->3559->2497->582->47->3438->4885->781->4465->2662->437->1024->4811->372->113->1075->1570->4807->592->4681->361->2002->1000->4514->3494
# Time taken by algorithm: 0.202 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  619
# Path Followed by algotithm: 2184->4746->4696->4563->873->699->1798->4585->1958->4923->2521->4974->3559->2497->582->47->3438->4885->781->4465->2662->437->1024->4811->372->113->1075->1570->4807->592->2250->434
# Time taken by algorithm: 0.196 seconds
#
#
#
#
#
# Results for Sparse Graph  5
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  608
# Path Followed by algotithm: 4747->2504->499->878->3626->1870->71->2796->1536->4141->2903->2564->2432->301->1443->3510->3384->4688->539->3879->3814->198->610->4515->2446->3244->3632->4409->579->4238->599->3769->4727->501->4904->3891->3146->1061->1397->4287->4897->1630->1076->2475->1555->2118->1181->3806->3310->1980->4011->2584->4964->4145->4651->4051
# Time taken by algorithm: 0.196 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  742
# Path Followed by algotithm: 4942->3157->1584->2298->3646->709->3679->1335->4145->4964->2584->4011->1980->3310->3806->1181->2118->1555->2475->1076->1630->4897->4287->1397->1061->3146->3891->4904->501->4727->3769->599->4238->579->4409->3632->3244->2446->4515->610->198->3814->3879->539->4688->3384->3510->1443->301->2432->2564->2903->4141->1536->2796->71->4775->2815->47->3043->2335->1149->180->1843->2482->1166->2369->4015
# Time taken by algorithm: 0.196 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  680
# Path Followed by algotithm: 3262->4054->1175->1547->540->4708->4240->529->4771->290->1->2621->95->4061->4230->2936->477->3495->501->4727->3769->599->4238->579->4409->3632->3244->2446->4515->610->41->2577->3849->4376->2960->2757->4851->2073->2374->2064->843->3658->1243->2882->3789->1199->438->4715->1404->3829->689->1124->3460->4222->868->4227->2191
# Time taken by algorithm: 0.196 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  592
# Path Followed by algotithm: 3076->924->2035->3022->1474->4569->2911->2941->1458->4082->3346->92->3956->276->2344->971->1980->3310->3806->1181->2118->1555->2475->1076->1630->4897->4287->1397->1061->3146->3891->4904->501->4727->3769->599->4238->579->4409->3632->3244->2446->4515->610->198->3814->3879->539->4688->3384->3510->1443->301->2432->2564->2903->4141->1536->2796->71->4775->2815->47->3043->2335->1149->180->1843->808->2724->3406->4126->2219->4451->213->3280->3195->1674->2449->1057->3839->3854->1109->1138->2212->2328->1161->4600->1256->786->1677->4421->2136->736->614->4088->1198->3494
# Time taken by algorithm: 0.197 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  766
# Path Followed by algotithm: 2184->3191->3696->4380->599->3769->4727->501->4904->3891->3146->1061->1397->4287->4897->1630->1076->2475->1555->2118->1181->3806->3310->1980->4011->2584->4387->1359->434
# Time taken by algorithm: 0.190 seconds

# %% [markdown]
# ### Testing Dijkstra's Algorithm without Heap on Dense Graph

# %%
bw4 = [[0]*5]*5
path4 = [['']*5]*5
time4 = [[0 for _ in range(5)] for _ in range(5)]
i = 0
for DenseGraph in DenseGraphs:
  j = 0
  print("Results for Sparse Graph ",i+1,'\n')
  for source, target in testSet:
    bw4[i][j], path4[i][j], time4[i][j] = Dijkstra_No_Heap(DenseGraph, source, target)
    print("Source: ",source,"\t"+"Target: ",target)
    print("Maximum Bandwidth: ", bw4[i][j])
    print("Path Followed by algotithm: "+path4[i][j])
    print("Time taken by algorithm: "+"%.3f seconds"%time4[i][j],'\n')
    j+=1
  print('\n\n\n')
  i+=1
# Out:
# Results for Sparse Graph  1
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998203
# Path Followed by algotithm: 4747->4906->1643->2002->741->3099->2079->2734->1531->1512->413->2275->2013->1061->1872->1214->1788->1443->3543->2277->300->1503->2514->2799->3776->3507->381->4160->4051
# Time taken by algorithm: 3.837 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  997107
# Path Followed by algotithm: 4942->426->349->684->719->1683->672->1940->1289->796->493->441->1535->1253->1397->23->136->1588->1600->143->1201->680->1075->1017->228->85->940->574->578->910->1400->952->774->182->1280->1154->412->442->1372->1278->1483->975->1276->3->1808->1907->287->979->698->2311->1445->2264->642->2760->1045->1992->4015
# Time taken by algorithm: 3.230 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998019
# Path Followed by algotithm: 3262->909->347->1950->2075->2884->2386->426->2975->458->412->1715->2190->1761->390->413->1512->1531->3->1808->569->1195->1842->114->2336->2153->267->817->2604->2044->1134->2191
# Time taken by algorithm: 0.676 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998788
# Path Followed by algotithm: 3076->347->909->4113->2615->1967->2091->511->2020->3941->1435->2861->1091->4052->2488->287->1907->3341->2897->4498->1991->1075->680->3905->172->376->390->413->2275->2013->1061->1872->1214->2322->2982->911->816->822->999->2334->4548->2298->964->1780->153->394->23->1397->241->1719->1911->2283->991->3245->4605->3099->2079->968->4599->1964->3367->1766->1697->1420->3468->4437->2893->2594->4853->1561->839->1660->4112->3976->3891->428->4390->557->4537->3045->1645->1125->4829->4198->1929->2209->2644->2487->3494
# Time taken by algorithm: 1.978 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998787
# Path Followed by algotithm: 2184->271->3684->3520->4686->2020->3941->1435->2861->1091->4052->142->4461->4979->1417->1324->1392->2899->2667->2419->1833->653->704->2254->2306->4364->2668->428->3891->3976->4112->1660->839->1561->4853->2594->2893->534->3175->3100->529->2145->2754->4258->2006->2694->2021->4257->3344->729->3433->723->259->2780->4462->434
# Time taken by algorithm: 1.959 seconds
#
#
#
#
#
# Results for Sparse Graph  2
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998021
# Path Followed by algotithm: 4747->2274->2531->542->654->196->233->341->2391->808->2343->1512->252->97->262->4->2373->272->2392->466->322->1526->1061->650->370->1716->1363->977->1832->1437->160->2251->2640->414->1036->4051
# Time taken by algorithm: 2.797 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998228
# Path Followed by algotithm: 4942->1950->2017->4286->1758->2987->3896->361->2038->1045->456->1623->751->889->1409->454->2962->2456->2708->1314->171->4410->3170->4277->404->1039->462->1588->2732->301->4015
# Time taken by algorithm: 3.951 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998667
# Path Followed by algotithm: 3262->431->4348->1447->1512->252->2824->4169->2954->394->1966->3219->2826->785->2893->2710->1287->3301->3620->549->1808->728->1928->3419->302->2291->1926->3762->4047->1803->2992->113->3842->1108->597->3100->601->2888->2791->3575->1943->1846->3420->2002->619->3316->1291->669->288->4339->2749->892->4694->3796->4498->886->2191
# Time taken by algorithm: 2.103 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  996772
# Path Followed by algotithm: 3076->4999->949->65->1444->293->395->311->837->463->447->958->531->572->709->216->457->544->863->980->1253->825->127->3494
# Time taken by algorithm: 2.779 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998369
# Path Followed by algotithm: 2184->2512->923->1045->456->1623->751->889->1409->454->1162->2745->626->2036->1952->3176->839->2905->1838->22->1498->31->601->2888->1480->1214->3138->2119->111->209->1201->1511->2351->434
# Time taken by algorithm: 0.362 seconds
#
#
#
#
#
# Results for Sparse Graph  3
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  997161
# Path Followed by algotithm: 4747->4831->2499->1498->1817->698->1776->1270->486->526->50->832->1027->30->1737->1015->1504->496->452->52->1458->488->1465->1329->1878->3330->4051
# Time taken by algorithm: 3.281 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998614
# Path Followed by algotithm: 4942->4553->650->2620->1303->1252->2254->15->4377->1531->1402->2827->2210->1493->4629->4760->2488->1069->2815->2440->7->4153->3894->3279->1489->448->513->1466->739->2872->346->192->2635->1806->366->4347->745->2009->2954->2059->701->2092->4171->4424->3239->3612->3254->4944->2405->786->1234->4015
# Time taken by algorithm: 3.075 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998571
# Path Followed by algotithm: 3262->4033->1808->1957->3248->1752->1057->1079->1927->233->25->1766->912->961->1807->1385->516->3165->815->194->3427->105->2635->192->346->206->1155->945->1951->3703->3089->3169->4713->209->4516->4828->1353->1189->4450->1702->2191
# Time taken by algorithm: 2.816 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998388
# Path Followed by algotithm: 3076->2939->1391->35->886->838->3447->3423->1870->3151->591->3141->3299->2037->1100->320->2219->3013->572->2832->357->2099->1573->1231->1772->752->646->689->2560->2062->1280->3007->1318->1246->1752->429->2210->2827->1402->784->2151->1035->30->1737->1015->1504->1499->1836->337->1036->773->3045->956->2300->2400->3078->72->343->2367->265->11->2678->2401->2828->2779->2108->1166->1049->2482->716->1113->3113->507->406->1966->3056->397->4393->3960->2950->3494
# Time taken by algorithm: 2.606 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998347
# Path Followed by algotithm: 2184->448->513->1466->739->4360->4867->4500->3917->1419->4291->388->434
# Time taken by algorithm: 3.674 seconds
#
#
#
#
#
# Results for Sparse Graph  4
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998111
# Path Followed by algotithm: 4747->570->2928->1758->1286->4672->3981->1569->2222->2090->4303->4351->3387->2819->3019->1225->3216->2172->295->2459->4278->783->4147->2697->2453->866->1084->1994->3876->3826->2470->1617->3008->1131->4371->3850->4514->4448->1753->3155->722->3498->4932->4021->3866->2772->4026->3986->4051
# Time taken by algorithm: 4.058 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  997873
# Path Followed by algotithm: 4942->2858->1150->3155->1753->4448->4514->3850->4371->1131->471->3931->148->92->1894->2819->3387->4351->4303->2090->2222->1569->3981->81->2351->1950->2078->26->2685->4015
# Time taken by algorithm: 4.305 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998297
# Path Followed by algotithm: 3262->3628->2532->1329->4303->4351->3387->2819->1894->92->148->3931->471->1131->4371->4580->2276->2889->2054->1621->3542->4038->4099->659->679->2334->4167->4205->368->3310->306->405->3063->4268->1762->3599->2053->2466->3301->1394->3708->2928->1758->1286->1749->3146->3388->993->1214->2234->4899->4994->3858->173->2304->1722->2191
# Time taken by algorithm: 3.757 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998408
# Path Followed by algotithm: 3076->4813->160->1796->320->693->2631->2976->1180->1882->787->2447->2552->367->2327->504->3138->961->1700->2522->1344->460->273->208->1229->139->470->307->978->567->1176->1587->2204->216->280->2835->3225->467->805->3050->1250->2252->1612->2484->641->3141->1894->2819->3019->1225->3216->2172->295->2459->153->550->1035->146->3301->1394->80->1540->3941->95->2801->93->918->2417->3000->3333->2360->2337->2914->2445->510->2653->2956->2070->654->37->3620->3456->3494
# Time taken by algorithm: 1.713 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  996740
# Path Followed by algotithm: 2184->2181->3740->1558->981->2620->618->325->528->1021->139->470->303->170->104->10->434
# Time taken by algorithm: 0.031 seconds
#
#
#
#
#
# Results for Sparse Graph  5
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  997905
# Path Followed by algotithm: 4747->1185->2796->2238->4196->1917->431->1868->1960->1433->2015->486->1866->1589->668->2167->2061->835->2053->792->628->1508->1217->1621->1707->2059->381->1167->732->721->1292->4414->4051
# Time taken by algorithm: 3.394 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998060
# Path Followed by algotithm: 4942->981->4573->2640->1208->3319->4754->3245->3285->3178->1037->3737->1014->821->734->1975->727->704->1333->800->175->1530->679->2153->305->2078->761->607->116->915->765->159->16->1495->1135->2964->1234->1866->486->2015->1433->1960->1868->431->2198->2056->1250->2742->2052->357->1787->3143->1940->2859->2926->1771->1429->3130->4015
# Time taken by algorithm: 4.081 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998646
# Path Followed by algotithm: 3262->3820->2033->2073->1946->1575->4002->2306->1546->360->3474->2118->326->1749->2887->2865->2706->1040->2929->2108->3290->3793->2553->3283->785->1735->168->175->800->2393->1270->442->936->3846->2289->2191
# Time taken by algorithm: 0.574 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  997820
# Path Followed by algotithm: 3076->4630->106->2910->2752->592->4544->2043->3730->3703->694->448->785->1735->168->175->1530->679->2153->305->2078->761->607->961->1487->539->2070->2465->865->906->3834->949->2871->4636->682->4980->4898->1329->3068->3494
# Time taken by algorithm: 4.342 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998416
# Path Followed by algotithm: 2184->4264->2479->1274->1912->2703->4556->2157->4545->722->1086->2443->1725->3412->1929->2655->4143->717->676->651->4361->1971->4109->700->3391->14->2904->350->4332->2114->49->705->2701->729->916->2870->2725->3027->1683->448->785->3283->2553->3793->3290->2108->2929->210->2726->2347->1812->2418->2956->2819->3866->1565->2494->460->2894->1790->1667->1540->1602->3455->610->2344->67->434
# Time taken by algorithm: 3.473 seconds

# %% [markdown]
# ### Testing Dijkstra's Algorithm with Heap on Dense Graph

# %%
bw5 = [[0]*5]*5
path5 = [['']*5]*5
time5 = [[0 for _ in range(5)] for _ in range(5)]
i = 0
for DenseGraph in DenseGraphs:
  j = 0
  print("Results for Sparse Graph ",i+1,'\n')
  for source, target in testSet:
    bw5[i][j], path5[i][j], time5[i][j] = Dijkstra_Heap(DenseGraph, source, target)
    print("Source: ",source,"\t"+"Target: ",target)
    print("Maximum Bandwidth: ", bw5[i][j])
    print("Path Followed by algotithm: "+path5[i][j])
    print("Time taken by algorithm: "+"%.3f seconds"%time5[i][j],'\n')
    j+=1
  print('\n\n\n')
  i+=1
# Out:
# Results for Sparse Graph  1
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998203
# Path Followed by algotithm: 4747->4906->1643->2002->4420->3426->2148->4223->4662->4698->4979->4461->2135->3958->1923->2323->3492->2590->2042->1456->2054->736->2315->4795->4573->4268->2514->2799->3776->3507->381->4160->4051
# Time taken by algorithm: 2.290 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  997107
# Path Followed by algotithm: 4942->426->2975->3731->2365->3179->3739->2654->3261->3940->3809->3545->3632->3299->4748->4009->3862->4508->4544->3620->3823->3984->4155->4185->3711->3677->3695->3486->3829->4399->4255->4557->3236->2502->3755->2760->1045->1992->4015
# Time taken by algorithm: 2.227 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998019
# Path Followed by algotithm: 3262->909->4330->2566->3060->3260->4642->3364->2725->2346->4830->4881->3589->4962->4885->3768->3901->4345->3420->3289->3646->3962->4946->2809->3558->3314->3821->2810->2604->2044->1134->2191
# Time taken by algorithm: 1.688 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998788
# Path Followed by algotithm: 3076->347->909->4113->2615->1967->2091->511->2020->4686->3520->3684->271->207->3938->1238->1211->2892->2855->778->4998->1976->4223->4662->4698->4979->1417->1324->1392->2899->2667->2419->1833->653->704->2254->2306->4364->2668->428->4390->557->4537->3045->1645->1125->4829->4198->1929->2209->2644->2487->3494
# Time taken by algorithm: 1.216 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998787
# Path Followed by algotithm: 2184->271->3684->3520->4686->2020->3941->1435->2861->1091->4052->142->4461->4979->1417->1324->1392->2899->2667->2419->1833->653->704->2254->2306->4364->2668->428->3891->3976->4112->1660->839->1561->4853->2594->2893->534->3175->3100->529->2145->2754->4258->2006->2694->2021->4257->3344->729->3433->723->259->2780->4462->434
# Time taken by algorithm: 1.239 seconds
#
#
#
#
#
# Results for Sparse Graph  2
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998021
# Path Followed by algotithm: 4747->2274->2531->542->4117->953->3821->4083->2282->3335->3947->3514->4240->2318->3300->3700->4521->2177->4380->4721->3465->4410->3170->2216->4500->3128->2721->4347->4427->4836->2357->4893->2996->2014->4993->3552->3863->4440->3677->2839->3880->4051
# Time taken by algorithm: 0.889 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998228
# Path Followed by algotithm: 4942->1950->2017->4286->1758->3931->4160->2327->2254->4351->2420->2136->4751->4247->2135->633->1893->1909->3740->1499->3489->3648->3945->3037->3416->3873->4367->4454->4484->4433->1546->3399->2376->4867->3210->4798->2360->1981->1177->4627->986->1625->4649->1925->3776->4887->4158->4176->4209->3095->1069->4096->809->4529->887->1963->3666->3895->1995->4538->2561->3215->4717->4576->1395->2261->1357->1377->4647->3609->2574->2401->4279->2675->2944->3329->3054->2659->1206->4078->1480->2888->2791->3575->1943->2718->1148->4504->778->3973->4146->1013->2067->2176->4487->3498->2562->4335->4464->3221->4249->4277->404->1039->462->1588->2732->301->4015
# Time taken by algorithm: 2.452 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998667
# Path Followed by algotithm: 3262->431->4348->1447->1512->252->2824->4323->1830->3785->3232->1061->4469->1074->1168->2451->4888->4916->4258->2014->4530->1741->2944->3329->3797->4610->3457->3969->4068->1598->3755->779->3359->3684->3817->465->4449->4339->2749->892->4694->3796->4498->886->2191
# Time taken by algorithm: 1.155 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  996772
# Path Followed by algotithm: 3076->4999->3870->3551->4811->3608->4247->4751->4606->4508->3860->4484->3190->4925->4469->4588->3841->3919->3494
# Time taken by algorithm: 0.661 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998369
# Path Followed by algotithm: 2184->2512->1940->1842->4191->4903->2928->2132->2182->2415->3472->2286->1412->3176->1952->3506->4169->2824->4323->1830->3785->2943->2216->3170->4410->3465->4721->4380->2177->4521->3700->3300->1792->4167->4383->3849->3311->4914->4504->3314->3447->2505->1838->3618->2205->2515->1877->4630->4992->4239->3021->2020->2617->2493->2079->2659->3054->3329->3797->4610->3457->3969->4068->1598->4728->4619->2938->1672->1773->3495->4889->4574->4987->2875->2500->2806->3952->1953->434
# Time taken by algorithm: 1.874 seconds
#
#
#
#
#
# Results for Sparse Graph  3
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  997161
# Path Followed by algotithm: 4747->4831->2499->3549->4980->4892->3358->4341->3047->4609->4484->3609->4343->4156->4019->3479->4886->3996->3588->3399->3852->4231->4286->3830->3842->3445->3331->4638->3932->4889->3402->3527->3752->3495->4714->3902->3853->4663->3294->3354->3128->4304->4239->3733->3005->2908->2720->3301->2374->4085->3330->4051
# Time taken by algorithm: 1.371 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998614
# Path Followed by algotithm: 4942->4553->650->2620->1303->1252->2254->15->4377->1531->1402->2827->2210->1493->4629->4760->1004->1868->2290->3518->3436->2048->4588->2437->4098->1629->3612->3254->4944->2405->786->1234->4015
# Time taken by algorithm: 1.755 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998571
# Path Followed by algotithm: 3262->4033->1808->1957->3248->1752->1057->1079->3370->3128->4304->4239->2564->3208->2106->4412->4568->2380->2108->2779->1672->1951->3703->3089->3169->4713->209->4516->4828->1353->1189->4450->1702->2191
# Time taken by algorithm: 1.760 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998388
# Path Followed by algotithm: 3076->2939->1391->35->886->838->3433->3647->1376->1627->4160->3027->4892->4939->2937->2985->4662->1774->2532->1739->3030->1843->4016->4303->1922->4476->4435->2716->2463->3487->3611->2102->4286->4231->3852->3399->3588->2889->2643->2782->3686->4789->2682->3972->2300->2400->2860->3700->3756->3520->3822->1951->1672->2779->2828->2388->2500->3782->4367->3506->2424->3122->3628->2231->2478->2830->1904->2876->3849->4162->3936->2268->2149->1986->3759->2608->3209->4685->3015->2010->3929->3941->3622->3543->2511->4504->1546->4995->399->2301->3494
# Time taken by algorithm: 1.879 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998347
# Path Followed by algotithm: 2184->448->513->1466->739->4360->4867->4500->3917->1419->4291->388->434
# Time taken by algorithm: 2.259 seconds
#
#
#
#
#
# Results for Sparse Graph  4
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998111
# Path Followed by algotithm: 4747->570->2928->1758->1286->4672->3981->1569->2222->2090->4303->4351->3387->2819->3019->1225->3216->2172->295->2459->4278->783->4147->2697->2453->866->1084->1994->3876->3826->2470->1617->3008->1131->4371->3850->4514->4448->1753->3155->722->3498->4932->4021->3866->2772->4026->3986->4051
# Time taken by algorithm: 2.488 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  997873
# Path Followed by algotithm: 4942->2858->1150->3155->1753->4448->4514->2185->4835->1575->4039->1858->1159->1405->2250->3959->4900->4264->1512->4317->4957->788->977->1505->3732->1450->3998->3819->3266->396->1350->480->3370->4543->1176->1587->2204->216->3638->428->920->839->1582->4576->1950->2078->26->2685->4015
# Time taken by algorithm: 2.633 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998297
# Path Followed by algotithm: 3262->3628->2532->1329->4303->2090->2222->1569->3981->4672->1286->1749->3146->3388->993->1214->2234->4899->4994->3858->173->2304->1722->2191
# Time taken by algorithm: 2.293 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998408
# Path Followed by algotithm: 3076->4813->160->1796->921->2505->3430->3182->2118->1943->2924->3240->3191->1524->1544->2296->3003->2616->2336->2276->4477->3733->4857->4460->4605->2499->4900->4758->3567->3931->4703->4409->2584->2558->2736->4069->4604->3251->3250->4247->3535->4464->3663->446->3843->4478->2253->1000->3494
# Time taken by algorithm: 1.803 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  996740
# Path Followed by algotithm: 2184->2181->4167->3712->2532->4708->3888->3967->3081->4706->4658->4976->3551->4886->4703->4409->4379->4595->3842->3568->4643->4991->3472->3199->3014->10->434
# Time taken by algorithm: 2.840 seconds
#
#
#
#
#
# Results for Sparse Graph  5
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  997905
# Path Followed by algotithm: 4747->1185->4659->4029->3986->2379->2387->2458->3146->2523->2533->3948->4191->4111->4819->2656->3066->2909->3463->2540->4779->3553->3438->4133->3823->3004->4056->3430->4926->3652->2225->2299->4790->2957->4414->4051
# Time taken by algorithm: 0.940 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998060
# Path Followed by algotithm: 4942->981->4573->2640->1208->3319->4754->3245->3285->3178->3736->2997->3762->2228->2100->3273->3445->4315->2819->4661->2114->4332->4287->3505->3626->3610->2880->2986->4216->1771->1429->3130->4015
# Time taken by algorithm: 2.567 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998646
# Path Followed by algotithm: 3262->3820->2033->2073->1946->1575->4002->2306->1546->1378->1721->3554->4682->4450->4817->4901->4014->4192->4349->4812->2608->4499->1138->3479->1496->3339->3519->1093->1317->721->3813->3680->3476->1651->1270->442->936->3846->2289->2191
# Time taken by algorithm: 1.383 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  997820
# Path Followed by algotithm: 3076->4630->106->2910->2752->592->4544->2043->3730->3703->694->448->1683->3027->2725->2870->916->729->4846->4907->4235->4314->4705->2465->865->906->3834->949->2871->4636->682->4980->4898->1329->3068->3494
# Time taken by algorithm: 2.727 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998416
# Path Followed by algotithm: 2184->4264->2479->1274->1912->2703->4556->2157->4545->722->2402->1698->4096->4924->1797->3299->2108->2929->1040->985->3232->1066->1633->3896->3401->3323->2651->591->610->2344->67->434
# Time taken by algorithm: 2.168 seconds

# %% [markdown]
# ### Testing Kruskal's Algorithm on Dense Graph

# %%
bw6 = [[0]*5]*5
path6 = [['']*5]*5
time6 = [[0 for _ in range(5)] for _ in range(5)]
timeG2 = [0 for _ in range(5)]
i = 0
for DenseGraph in DenseGraphs:
  j = 0
  T, timeG2[i] = Kruskal(DenseGraph)
  print("Results for Sparse Graph ",i+1,'\n')
  for source, target in testSet:
    bw6[i][j], path6[i][j], time6[i][j] = bfs(T,source,target)
    print("Source: ",source,"\t"+"Target: ",target)
    print("Maximum Bandwidth: ", bw6[i][j])
    print("Path Followed by algotithm: "+path6[i][j])
    print("Time taken by algorithm: "+"%.3f seconds"%(timeG2[i]+time6[i][j]),'\n')
    j+=1
  print('\n\n\n')
  i+=1
# Out:
# Results for Sparse Graph  1
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998203
# Path Followed by algotithm: 4747->4906->1643->2002->4420->3426->2148->4223->4662->4698->4979->4461->142->4052->1091->2861->1435->3941->2020->4686->2187->2140->1658->4876->1148->2154->2738->691->2725->3364->4642->3260->605->3068->146->3842->3029->2277->300->1503->2514->2799->3776->3507->381->4160->4051
# Time taken by algorithm: 45.480 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  997107
# Path Followed by algotithm: 4942->426->2975->458->412->1154->3664->2805->4689->3222->1149->360->2855->778->4998->1976->4223->4662->4698->4979->1417->1324->1392->2899->2667->2419->1833->653->2424->708->2753->642->2760->1045->1992->4015
# Time taken by algorithm: 45.474 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998019
# Path Followed by algotithm: 3262->909->4113->2615->1967->2091->511->2020->3941->1435->2861->1091->4052->2488->287->979->698->712->4899->3122->1502->2827->4596->2692->541->2191
# Time taken by algorithm: 45.473 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998788
# Path Followed by algotithm: 3076->347->909->4113->2615->1967->2091->511->2020->3941->1435->2861->1091->4052->142->4461->4979->1417->1324->1392->2899->2667->2419->1833->653->704->2254->2306->4364->2668->428->4390->557->4537->3045->1645->1125->4829->4198->1929->2209->2644->2487->3494
# Time taken by algorithm: 45.478 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998787
# Path Followed by algotithm: 2184->271->3684->3520->4686->2020->3941->1435->2861->1091->4052->142->4461->4979->1417->1324->1392->2899->2667->2419->1833->653->704->2254->2306->4364->2668->428->3891->3976->4112->1660->839->1561->4853->2594->2893->534->3175->3100->529->2145->2754->4258->2006->2694->2021->4257->3344->729->3433->723->259->2780->4462->434
# Time taken by algorithm: 45.481 seconds
#
#
#
#
#
# Results for Sparse Graph  2
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998021
# Path Followed by algotithm: 4747->2274->2531->542->654->2837->564->369->1692->4918->3960->2138->2745->1162->454->1409->3367->1711->1526->1061->2057->3328->249->1284->4248->508->4455->2904->4444->2128->875->2045->855->2289->3648->4688->695->160->2905->1838->1768->976->3938->4051
# Time taken by algorithm: 43.772 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998228
# Path Followed by algotithm: 4942->1950->2017->4286->1758->3931->4160->2327->2254->4351->2420->2136->4751->4247->2135->633->1575->3146->71->3938->976->1768->1838->2905->160->695->4688->3648->2289->855->2045->875->2128->4444->2904->4455->508->4248->1284->249->3328->2057->1061->4469->1074->1168->2451->4888->4916->4258->2014->4530->1741->2944->3329->3797->4610->3457->3969->4068->1598->2595->290->4464->3221->4249->4277->404->1039->462->1588->2732->301->4015
# Time taken by algorithm: 43.771 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998667
# Path Followed by algotithm: 3262->431->4348->1447->1512->252->1896->555->4754->463->3366->1399->3684->3817->465->4449->4339->2749->892->4694->3796->4498->886->2191
# Time taken by algorithm: 43.767 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  996772
# Path Followed by algotithm: 3076->4999->3350->3441->1621->1908->2158->3374->1534->1335->2172->2213->2283->850->1823->1963->3666->3895->1995->4538->2561->3215->1585->1483->98->302->2291->1926->3611->1636->4193->3863->3552->4993->353->2637->1617->933->946->2145->4568->1546->3399->3814->660->3501->2748->1287->234->127->3494
# Time taken by algorithm: 43.772 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998369
# Path Followed by algotithm: 2184->2512->1940->1842->4191->4903->1626->464->3864->1549->1168->4458->4376->434
# Time taken by algorithm: 43.766 seconds
#
#
#
#
#
# Results for Sparse Graph  3
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  997161
# Path Followed by algotithm: 4747->4831->2499->3549->4980->4306->471->635->1106->883->2645->3573->3776->644->3958->1262->1927->1079->3370->3128->4304->4239->4327->2184->448->1489->3279->3894->4153->7->2440->4615->3836->3132->1978->2057->1819->207->932->2863->3624->4928->3705->70->720->1878->3330->4051
# Time taken by algorithm: 42.284 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998614
# Path Followed by algotithm: 4942->4553->650->2620->1303->1252->2254->15->4377->1531->1402->2827->2210->1493->4629->4760->1004->1868->2290->3518->3436->2048->4588->2437->4098->1629->3612->3254->4944->2405->786->1234->4015
# Time taken by algorithm: 42.280 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998571
# Path Followed by algotithm: 3262->4033->1808->1957->3248->1752->3747->1814->3201->1021->1231->1573->4007->1589->2705->4761->4772->1221->349->591->3141->3299->2037->1100->2977->2976->818->1348->4792->1397->4164->2448->2575->1764->1009->490->1672->1951->3703->3089->3169->4713->209->4516->4828->1353->1189->4450->1702->2191
# Time taken by algorithm: 42.279 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998388
# Path Followed by algotithm: 3076->2939->1391->35->886->838->3433->2452->588->1708->3958->1262->1927->3537->1562->4852->553->2975->1649->945->1951->1672->490->1009->1764->1374->3417->2268->2149->1986->3759->2608->137->3965->397->4393->3960->2950->3494
# Time taken by algorithm: 42.282 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998347
# Path Followed by algotithm: 2184->448->513->1466->739->4360->4867->4500->3917->1419->4291->388->434
# Time taken by algorithm: 42.278 seconds
#
#
#
#
#
# Results for Sparse Graph  4
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  998111
# Path Followed by algotithm: 4747->570->2928->1758->1286->4672->3981->1569->2222->2090->4303->4351->3387->2819->3019->1225->3216->2172->295->2459->4278->783->4147->2697->2453->866->1084->1994->3876->3826->2470->1617->3008->1131->4371->3850->4514->4448->1753->3155->722->3498->4932->4021->3866->2772->4026->3986->4051
# Time taken by algorithm: 41.968 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  997873
# Path Followed by algotithm: 4942->2858->1150->3155->1753->4448->4514->3850->4371->1131->3008->1617->2470->3826->3876->1994->1084->866->2453->4223->3251->4604->2654->2631->693->320->1796->921->1505->3732->1450->3998->3819->3266->396->1350->480->3370->4543->1176->1587->2204->216->3638->428->920->839->1582->4576->1950->2078->26->2685->4015
# Time taken by algorithm: 41.967 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998297
# Path Followed by algotithm: 3262->3628->2532->1329->4303->2090->2222->1569->3981->4672->1286->1749->3146->3388->993->1214->2234->4899->4994->3858->173->2304->1722->2191
# Time taken by algorithm: 41.962 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  998408
# Path Followed by algotithm: 3076->4813->160->1796->320->693->2631->2654->4604->3251->4223->2453->866->1084->1994->3876->4995->4464->3663->446->3843->4478->2253->1000->3494
# Time taken by algorithm: 41.961 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  996740
# Path Followed by algotithm: 2184->2181->4167->2334->679->659->4099->4038->3542->1621->2054->2889->2276->4580->4371->1131->3008->1617->2470->3826->3876->1994->1084->866->2453->2697->4147->783->4278->2459->295->2172->3216->1225->3019->2819->3387->4351->4303->2090->2222->1501->3560->1866->4803->1258->2788->976->2836->1436->348->845->4221->3785->304->4479->4209->1499->2896->139->3132->4032->104->10->434
# Time taken by algorithm: 41.967 seconds
#
#
#
#
#
# Results for Sparse Graph  5
#
# Source:  4747 	Target:  4051
# Maximum Bandwidth:  997905
# Path Followed by algotithm: 4747->1185->2796->2238->4196->1917->1348->362->4911->3913->784->3698->758->2201->724->1421->3701->3546->253->1782->1790->2894->460->2494->1565->3866->4799->1366->2488->418->700->3391->3585->4846->4907->4235->4314->4705->2886->2963->1002->4974->52->1182->3305->1399->743->3137->3103->2706->1040->985->3232->1066->1633->3896->4822->2958->2957->4414->4051
# Time taken by algorithm: 39.193 seconds
#
# Source:  4942 	Target:  4015
# Maximum Bandwidth:  998060
# Path Followed by algotithm: 4942->981->4573->2640->4999->1793->3795->307->4836->3984->2872->614->60->136->1804->415->2361->4423->733->825->266->2786->2153->4018->379->2955->4803->2026->3161->146->1979->626->4014->4901->4817->4450->4301->2002->354->1788->2428->3989->3896->1633->1066->3232->985->1040->2706->3103->3137->743->1399->3305->1182->52->4974->1002->2963->2886->4705->4314->4235->4907->4846->3585->3391->700->418->2488->1366->4799->3866->1565->2494->460->2894->1790->1667->1540->4216->1771->1429->3130->4015
# Time taken by algorithm: 39.198 seconds
#
# Source:  3262 	Target:  2191
# Maximum Bandwidth:  998646
# Path Followed by algotithm: 3262->3820->2033->4120->1487->961->607->761->2078->305->2153->4018->379->2955->4803->2026->3161->146->1979->626->4014->4901->4817->4450->4301->2002->354->1788->2428->3989->3896->1633->1066->3232->985->1040->2706->2865->2887->1749->326->1426->3191->4191->589->1418->2683->3420->4985->3584->3648->3730->3703->694->448->785->1735->168->175->800->2393->1270->442->936->3846->2289->2191
# Time taken by algorithm: 39.196 seconds
#
# Source:  3076 	Target:  3494
# Maximum Bandwidth:  997820
# Path Followed by algotithm: 3076->4630->106->2910->2752->592->4544->2043->3730->3648->3584->4985->3420->2683->1418->589->4191->3191->1426->326->1749->2887->2865->2706->3103->3137->743->1399->3305->1182->52->4974->1002->2963->2886->4705->4314->4235->4907->4846->3585->3391->700->418->2488->1366->4799->3866->1565->2494->460->2894->1790->1782->2012->3315->3367->3143->1787->357->4327->2871->4636->682->4980->4898->1329->3068->3494
# Time taken by algorithm: 39.197 seconds
#
# Source:  2184 	Target:  434
# Maximum Bandwidth:  998416
# Path Followed by algotithm: 2184->4264->2479->1274->1912->2703->4556->4708->915->548->3380->487->492->1076->1865->3652->709->3888->916->729->4846->3585->3391->700->418->2488->1366->4799->3866->1565->2494->460->2894->1790->1667->1540->1602->3455->610->2344->67->434
# Time taken by algorithm: 39.191 seconds

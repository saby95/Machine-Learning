# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('buildings_incidents_roads.csv')

# %%
df
# Out:
#        TIME BIN  ROAD_BIN  NO OF BUILDINGS IN WORK  NO OF INCIDENTS REPORTED
# 0             6     99704                       46                         1
# 1            10     79094                        1                         1
# 2            20     24048                      153                         1
# 3            21     19012                        1                         1
# 4            21     20537                        9                         1
# 5            23      8412                        2                         1
# 6            24    121242                        2                         1
# 7            25    117074                        9                         1
# 8            26    110421                       17                         1
# 9            26    110707                        2                         1
# 10           26    112437                        4                         1
# ...

# %%
from matplotlib import pyplot as plt

# %%
buildings = df['NO OF BUILDINGS IN WORK'].values.tolist()
incidents = df['NO OF INCIDENTS REPORTED'].values.tolist()

# %%
plt.scatter(buildings,incidents)
plt.xlabel('NO OF CONSTRUCTIONS IN A STREET IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
plt.savefig('Buildings_vs_Incidents_roads')
plt.show()

# %%
df_2012 = df[df['TIME BIN']<13]
df_2013 = df[df['TIME BIN']>12]
df_2013 = df_2013[df_2013['TIME BIN']<25]
df_2014 = df[df['TIME BIN']>24]
df_2014 = df_2014[df_2014['TIME BIN']<37]
df_2015 = df[df['TIME BIN']>36]
df_2015 = df_2015[df_2015['TIME BIN']<49]
df_2016 = df[df['TIME BIN']>48]
df_2016 = df_2016[df_2016['TIME BIN']<61]
df_2017 = df[df['TIME BIN']>60]
df_2017 = df_2017[df_2017['TIME BIN']<73]
df_2018 = df[df['TIME BIN']>72]
df_2018 = df_2018[df_2018['TIME BIN']<85]
df_2019 = df[df['TIME BIN']>84]

# %%
buildings_2012 = df_2012['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2012 = df_2012['NO OF INCIDENTS REPORTED'].values.tolist()
buildings_2013 = df_2013['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2013 = df_2013['NO OF INCIDENTS REPORTED'].values.tolist()
buildings_2014 = df_2014['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2014 = df_2014['NO OF INCIDENTS REPORTED'].values.tolist()
buildings_2015 = df_2015['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2015 = df_2015['NO OF INCIDENTS REPORTED'].values.tolist()
buildings_2016 = df_2016['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2016 = df_2016['NO OF INCIDENTS REPORTED'].values.tolist()
buildings_2017 = df_2017['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2017 = df_2017['NO OF INCIDENTS REPORTED'].values.tolist()
buildings_2018 = df_2018['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2018 = df_2018['NO OF INCIDENTS REPORTED'].values.tolist()
buildings_2019 = df_2019['NO OF BUILDINGS IN WORK'].values.tolist()
incidents_2019 = df_2019['NO OF INCIDENTS REPORTED'].values.tolist()

# %%
plt.scatter(buildings_2012,incidents_2012)
plt.xlabel('NO OF CONSTRUCTIONS IN A BIN IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2012,[-1,1])
incs = np.reshape(incidents_2012,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2012')
plt.show()

# %%
plt.scatter(buildings_2013,incidents_2013)
plt.xlabel('NO OF CONSTRUCTIONS IN A BIN IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2013,[-1,1])
incs = np.reshape(incidents_2013,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2013')
plt.show()

# %%
plt.scatter(buildings_2014,incidents_2014)
plt.xlabel('NO OF CONSTRUCTIONS IN A BIN IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2014,[-1,1])
incs = np.reshape(incidents_2014,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2014')
plt.show()

# %%
plt.scatter(buildings_2015,incidents_2015)
plt.xlabel('NO OF CONSTRUCTIONS IN A BIN IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2015,[-1,1])
incs = np.reshape(incidents_2015,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2015')
plt.show()

# %%
plt.scatter(buildings_2016,incidents_2016)
plt.xlabel('NO OF CONSTRUCTIONS IN A STREET IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2016,[-1,1])
incs = np.reshape(incidents_2016,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2016_road')
plt.show()

# %%
plt.scatter(buildings_2017,incidents_2017)
plt.xlabel('NO OF CONSTRUCTIONS IN A STREET IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2017,[-1,1])
incs = np.reshape(incidents_2017,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2017_road')
plt.show()

# %%
plt.scatter(buildings_2018,incidents_2018)
plt.xlabel('NO OF CONSTRUCTIONS IN A STREET IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2018,[-1,1])
incs = np.reshape(incidents_2018,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2018_road')
plt.show()

# %%
plt.scatter(buildings_2019,incidents_2019)
plt.xlabel('NO OF CONSTRUCTIONS IN A STREET IN A PARTICULAR MONTH')
plt.ylabel('INCIDENTS REPORTED')
builds = np.reshape(buildings_2019,[-1,1])
incs = np.reshape(incidents_2019,[-1,1])
lin1.fit(builds,incs)
plt.plot(builds,lin1.predict(builds), color='k')
plt.savefig('Buildings_vs_incidents_2019_road')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-512800a1e243> in <module>()
#       4 builds = np.reshape(buildings_2019,[-1,1])
#       5 incs = np.reshape(incidents_2019,[-1,1])
# ----> 6 lin1.fit(builds,incs)
#       7 plt.plot(builds,lin1.predict(builds), color='k')
#       8 plt.savefig('Buildings_vs_incidents_2019_road')
#
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lin1 = LinearRegression()

# %%
len(df_2019)
# Out:
# 0
